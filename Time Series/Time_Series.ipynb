# %% [markdown]
# # Predicción de Series Temporales con Redes Neuronales

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('fast')

from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('time_series.csv',  parse_dates=[0], header=None,index_col=0, squeeze=True,names=['fecha','unidades'])
df.head()
# Out:
# fecha
# 2017-01-02    236
# 2017-01-03    237
# 2017-01-04    290
# 2017-01-05    221
# 2017-01-07    128
# Name: unidades, dtype: int64

# %%
print(df.index.min())
print(df.index.max())
# Out:
# 2017-01-02 00:00:00
# 2018-11-30 00:00:00

# %%
print(len(df['2017']))
print(len(df['2018']))

df.describe()
# Out:
# 315
# 289
# count    604.000000
# mean     215.935430
# std       75.050304
# min       51.000000
# 25%      171.000000
# 50%      214.000000
# 75%      261.250000
# max      591.000000
# Name: unidades, dtype: float64

# %%
meses =df.resample('M').mean()
meses
# Out:
# fecha
# 2017-01-31    203.923077
# 2017-02-28    184.666667
# 2017-03-31    182.964286
# 2017-04-30    198.960000
# 2017-05-31    201.185185
# 2017-06-30    209.518519
# 2017-07-31    278.923077
# 2017-08-31    316.000000
# 2017-09-30    222.925926
# 2017-10-31    207.851852
# 2017-11-30    185.925926
# 2017-12-31    213.200000
# 2018-01-31    201.384615
# 2018-02-28    190.625000
# 2018-03-31    174.846154
# 2018-04-30    186.000000
# 2018-05-31    190.666667
# 2018-06-30    196.037037
# 2018-07-31    289.500000
# 2018-08-31    309.038462
# 2018-09-30    230.518519
# 2018-10-31    209.444444
# 2018-11-30    184.481481
# Freq: M, Name: unidades, dtype: float64

# %%
plt.plot(meses['2017'].values)
plt.plot(meses['2018'].values)

# %%
verano2017 = df['2017-06-01':'2017-09-01']
plt.plot(verano2017.values)
verano2018 = df['2018-06-01':'2018-09-01']
plt.plot(verano2018.values)

# %% [markdown]
# # Procesando los datos

# %%
PASOS=7

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df.values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7   -0.314815  -0.311111  -0.114815  -0.370370  -0.714815  -0.103704
# 8   -0.311111  -0.114815  -0.370370  -0.714815  -0.103704  -0.225926
# 9   -0.114815  -0.370370  -0.714815  -0.103704  -0.225926  -0.433333
# 10  -0.370370  -0.714815  -0.103704  -0.225926  -0.433333  -0.607407
# 11  -0.714815  -0.103704  -0.225926  -0.433333  -0.607407  -0.522222
#
#     var1(t-1)   var1(t)
# 7   -0.225926 -0.433333
# 8   -0.433333 -0.607407
# 9   -0.607407 -0.522222
# 10  -0.522222 -0.644444
# 11  -0.644444 -0.344444

# %%
# split into train and test sets
values = reframed.values
n_train_days = 315+289 - (30+PASOS)
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split into input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (567, 1, 7) (567,) (30, 1, 7) (30,)

# %%
def crear_modeloFF():
    model = Sequential() 
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %% [markdown]
# # Entrenamiento y Resultados

# %%
EPOCHS=40

model = crear_modeloFF()

history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1, 7)              56
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 8
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 567 samples, validate on 30 samples
# Epoch 1/40
# 567/567 [==============================] - 0s 405us/step - loss: 0.2621 - mean_squared_error: 0.1112 - val_loss: 0.2147 - val_mean_squared_error: 0.0720
# Epoch 2/40
# 567/567 [==============================] - 0s 135us/step - loss: 0.2345 - mean_squared_error: 0.0892 - val_loss: 0.1914 - val_mean_squared_error: 0.0588
# Epoch 3/40
# 567/567 [==============================] - 0s 139us/step - loss: 0.2133 - mean_squared_error: 0.0765 - val_loss: 0.1739 - val_mean_squared_error: 0.0512
# Epoch 4/40
# 567/567 [==============================] - 0s 145us/step - loss: 0.1992 - mean_squared_error: 0.0683 - val_loss: 0.1655 - val_mean_squared_error: 0.0438
# Epoch 5/40
# 567/567 [==============================] - 0s 151us/step - loss: 0.1882 - mean_squared_error: 0.0613 - val_loss: 0.1514 - val_mean_squared_error: 0.0398
# Epoch 6/40
# 567/567 [==============================] - 0s 146us/step - loss: 0.1794 - mean_squared_error: 0.0577 - val_loss: 0.1465 - val_mean_squared_error: 0.0382
# Epoch 7/40
# 567/567 [==============================] - 0s 163us/step - loss: 0.1757 - mean_squared_error: 0.0565 - val_loss: 0.1422 - val_mean_squared_error: 0.0367
# Epoch 8/40
# 567/567 [==============================] - 0s 134us/step - loss: 0.1734 - mean_squared_error: 0.0560 - val_loss: 0.1403 - val_mean_squared_error: 0.0366
# Epoch 9/40
# 567/567 [==============================] - 0s 134us/step - loss: 0.1719 - mean_squared_error: 0.0549 - val_loss: 0.1404 - val_mean_squared_error: 0.0368
# Epoch 10/40
# 567/567 [==============================] - 0s 134us/step - loss: 0.1705 - mean_squared_error: 0.0548 - val_loss: 0.1384 - val_mean_squared_error: 0.0355
# Epoch 11/40
# 567/567 [==============================] - 0s 137us/step - loss: 0.1702 - mean_squared_error: 0.0542 - val_loss: 0.1373 - val_mean_squared_error: 0.0354
# Epoch 12/40
# 567/567 [==============================] - 0s 165us/step - loss: 0.1694 - mean_squared_error: 0.0543 - val_loss: 0.1370 - val_mean_squared_error: 0.0354
# Epoch 13/40
# 567/567 [==============================] - 0s 155us/step - loss: 0.1694 - mean_squared_error: 0.0543 - val_loss: 0.1376 - val_mean_squared_error: 0.0351
# Epoch 14/40
# 567/567 [==============================] - 0s 157us/step - loss: 0.1683 - mean_squared_error: 0.0542 - val_loss: 0.1442 - val_mean_squared_error: 0.0352
# Epoch 15/40
# 567/567 [==============================] - 0s 147us/step - loss: 0.1692 - mean_squared_error: 0.0550 - val_loss: 0.1384 - val_mean_squared_error: 0.0345
# Epoch 16/40
# 567/567 [==============================] - 0s 137us/step - loss: 0.1677 - mean_squared_error: 0.0545 - val_loss: 0.1379 - val_mean_squared_error: 0.0346
# Epoch 17/40
# 567/567 [==============================] - 0s 134us/step - loss: 0.1681 - mean_squared_error: 0.0547 - val_loss: 0.1389 - val_mean_squared_error: 0.0345
# Epoch 18/40
# 567/567 [==============================] - 0s 135us/step - loss: 0.1681 - mean_squared_error: 0.0552 - val_loss: 0.1428 - val_mean_squared_error: 0.0349
# Epoch 19/40
# 567/567 [==============================] - 0s 139us/step - loss: 0.1681 - mean_squared_error: 0.0550 - val_loss: 0.1377 - val_mean_squared_error: 0.0346
# Epoch 20/40
# 567/567 [==============================] - 0s 131us/step - loss: 0.1672 - mean_squared_error: 0.0548 - val_loss: 0.1372 - val_mean_squared_error: 0.0346
# Epoch 21/40
# 567/567 [==============================] - 0s 136us/step - loss: 0.1682 - mean_squared_error: 0.0548 - val_loss: 0.1405 - val_mean_squared_error: 0.0348
# Epoch 22/40
# 567/567 [==============================] - 0s 140us/step - loss: 0.1675 - mean_squared_error: 0.0542 - val_loss: 0.1368 - val_mean_squared_error: 0.0346
# Epoch 23/40
# 567/567 [==============================] - 0s 131us/step - loss: 0.1676 - mean_squared_error: 0.0549 - val_loss: 0.1376 - val_mean_squared_error: 0.0348
# Epoch 24/40
# 567/567 [==============================] - 0s 136us/step - loss: 0.1674 - mean_squared_error: 0.0545 - val_loss: 0.1375 - val_mean_squared_error: 0.0348
# Epoch 25/40
# 567/567 [==============================] - 0s 136us/step - loss: 0.1670 - mean_squared_error: 0.0550 - val_loss: 0.1412 - val_mean_squared_error: 0.0347
# Epoch 26/40
# 567/567 [==============================] - 0s 131us/step - loss: 0.1688 - mean_squared_error: 0.0546 - val_loss: 0.1374 - val_mean_squared_error: 0.0359
# Epoch 27/40
# 567/567 [==============================] - 0s 127us/step - loss: 0.1675 - mean_squared_error: 0.0546 - val_loss: 0.1409 - val_mean_squared_error: 0.0370
# Epoch 28/40
# 567/567 [==============================] - 0s 138us/step - loss: 0.1664 - mean_squared_error: 0.0541 - val_loss: 0.1378 - val_mean_squared_error: 0.0347
# Epoch 29/40
# 567/567 [==============================] - 0s 137us/step - loss: 0.1666 - mean_squared_error: 0.0542 - val_loss: 0.1374 - val_mean_squared_error: 0.0348
# Epoch 30/40
# 567/567 [==============================] - 0s 135us/step - loss: 0.1673 - mean_squared_error: 0.0548 - val_loss: 0.1369 - val_mean_squared_error: 0.0347
# Epoch 31/40
# 567/567 [==============================] - 0s 132us/step - loss: 0.1662 - mean_squared_error: 0.0542 - val_loss: 0.1375 - val_mean_squared_error: 0.0357
# Epoch 32/40
# 567/567 [==============================] - 0s 131us/step - loss: 0.1666 - mean_squared_error: 0.0546 - val_loss: 0.1364 - val_mean_squared_error: 0.0343
# Epoch 33/40
# 567/567 [==============================] - 0s 130us/step - loss: 0.1664 - mean_squared_error: 0.0543 - val_loss: 0.1364 - val_mean_squared_error: 0.0343
# Epoch 34/40
# 567/567 [==============================] - 0s 137us/step - loss: 0.1666 - mean_squared_error: 0.0548 - val_loss: 0.1372 - val_mean_squared_error: 0.0343
# Epoch 35/40
# 567/567 [==============================] - 0s 138us/step - loss: 0.1665 - mean_squared_error: 0.0545 - val_loss: 0.1393 - val_mean_squared_error: 0.0343
# Epoch 36/40
# 567/567 [==============================] - 0s 132us/step - loss: 0.1672 - mean_squared_error: 0.0542 - val_loss: 0.1369 - val_mean_squared_error: 0.0355
# Epoch 37/40
# 567/567 [==============================] - 0s 132us/step - loss: 0.1661 - mean_squared_error: 0.0547 - val_loss: 0.1366 - val_mean_squared_error: 0.0344
# Epoch 38/40
# 567/567 [==============================] - 0s 136us/step - loss: 0.1663 - mean_squared_error: 0.0541 - val_loss: 0.1362 - val_mean_squared_error: 0.0353
# Epoch 39/40
# 567/567 [==============================] - 0s 135us/step - loss: 0.1676 - mean_squared_error: 0.0549 - val_loss: 0.1366 - val_mean_squared_error: 0.0342
# Epoch 40/40
# 567/567 [==============================] - 0s 132us/step - loss: 0.1668 - mean_squared_error: 0.0544 - val_loss: 0.1372 - val_mean_squared_error: 0.0342

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()

# %%
plt.title('Accuracy')
plt.plot(history.history['mean_squared_error'])
plt.show()

# %%
ultimosDias = df['2018-11-16':'2018-11-30']
ultimosDias
# Out:
# fecha
# 2018-11-16    152
# 2018-11-17    111
# 2018-11-19    207
# 2018-11-20    206
# 2018-11-21    183
# 2018-11-22    200
# 2018-11-23    187
# 2018-11-24    189
# 2018-11-25     76
# 2018-11-26    276
# 2018-11-27    220
# 2018-11-28    183
# 2018-11-29    251
# 2018-11-30    189
# Name: unidades, dtype: int64

# %%
values = ultimosDias.values
values = values.astype('float32')
# normalize features
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.drop(reframed.columns[[7]], axis=1, inplace=True)
reframed.head(7)
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7       -0.24      -0.65       0.31       0.30       0.07       0.24
# 8       -0.65       0.31       0.30       0.07       0.24       0.11
# 9        0.31       0.30       0.07       0.24       0.11       0.13
# 10       0.30       0.07       0.24       0.11       0.13      -1.00
# 11       0.07       0.24       0.11       0.13      -1.00       1.00
# 12       0.24       0.11       0.13      -1.00       1.00       0.44
# 13       0.11       0.13      -1.00       1.00       0.44       0.07
#
#     var1(t-1)
# 7        0.11
# 8        0.13
# 9       -1.00
# 10       1.00
# 11       0.44
# 12       0.07
# 13       0.75

# %%
values = reframed.values
x_test = values[6:, :]
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
x_test
# Out:
# array([[[ 0.11000001,  0.13      , -1.        ,  1.        ,
#           0.44000006,  0.06999993,  0.75      ]]], dtype=float32)

# %%
def agregarNuevoValor(x_test,nuevoValor):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i] = x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1]=nuevoValor
    return x_test

results=[]
for i in range(7):
    parcial=model.predict(x_test)
    results.append(parcial[0])
    print(x_test)
    x_test=agregarNuevoValor(x_test,parcial[0])
# Out:
# [[[ 0.11000001  0.13       -1.          1.          0.44000006
#     0.06999993  0.75      ]]]
# [[[ 0.13       -1.          1.          0.44000006  0.06999993
#     0.75       -0.08642584]]]
# [[[-1.          1.          0.44000006  0.06999993  0.75
#    -0.08642584 -0.39647454]]]
# [[[ 1.          0.44000006  0.06999993  0.75       -0.08642584
#    -0.39647454  0.27290845]]]
# [[[ 0.44000006  0.06999993  0.75       -0.08642584 -0.39647454
#     0.27290845  0.1724895 ]]]
# [[[ 0.06999993  0.75       -0.08642584 -0.39647454  0.27290845
#     0.1724895  -0.03622396]]]
# [[[ 0.75       -0.08642584 -0.39647454  0.27290845  0.1724895
#    -0.03622396  0.28100705]]]

# %%
adimen = [x for x in results]    
inverted = scaler.inverse_transform(adimen)
inverted
# Out:
# array([[167.3574187 ],
#        [136.35254807],
#        [203.29084851],
#        [193.24895277],
#        [172.37760735],
#        [204.10070876],
#        [164.32775403]])

# %%
prediccion1SemanaDiciembre = pd.DataFrame(inverted)
prediccion1SemanaDiciembre.columns = ['pronostico']
prediccion1SemanaDiciembre.plot()
prediccion1SemanaDiciembre.to_csv('pronostico.csv')
